# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_q1= pd.read_csv('/content/drive/MyDrive/Energy_project/renewable Q1.csv')
df_q2= pd.read_csv('/content/drive/MyDrive/Energy_project/renewable Q2.csv')

# %%
display(df_q1.head())
display(df_q2.head())
# Out:
#    #     project_name   Type  Capacity_GW  Tendering_Year  \
# 0  1           Sakaka  Solar          0.3            2017
# 1  2  Dumat al-Jandal   Wind          0.4            2017
# 2  3         Rabigh 1  Solar          0.3            2019
# 3  4           Sudair  Solar          1.5            2019
# 4  5        Ar Rass 1  Solar          0.7            2020
#
#    Expected_Commissioning_Year      Region Round_No                 Status  \
# 0                         2020    Al-Jawf   Round 1  Connected to the grid
# 1                         2022    Al-Jawf   Round 1  Connected to the grid
# 2                         2023     Makkah   Round 2  Connected to the grid
# 3                         2023     Riyadh       PIF  Connected to the grid
# 4                         2024  Al-Qassim   Round 3  Connected to the grid
#
#                 Developer LCOE (US Cent/kWh)        lat        lon  \
# 0              ACWA Power               2.34  29.912900  40.053300
# 1  Masdar, EDF Renewables               2.13  29.809800  39.880700
# 2    MARUBENI Corporation                1.7  22.795500  39.002900
# 3              ACWA Power               1.24  25.775409  45.580238
# 4              ACWA Power                1.5  25.859700  43.489900
#
#   Is_Grid_connected
# 0     National Grid
# 1     National Grid
# 2     National Grid
# 3     National Grid
# 4     National Grid
#    #     project_name   Type  Capacity_GW  Tendering_Year  \
# 0  1           Sakaka  Solar          0.3            2017
# 1  2  Dumat al-Jandal   Wind          0.4            2017
# 2  3         Rabigh 1  Solar          0.3            2019
# 3  4           Sudair  Solar          1.5            2019
# 4  5        Ar Rass 1  Solar          0.7            2020
#
#    Expected_Commissioning_Year      Region Round_No                 Status  \
# 0                         2020    Al-Jawf   Round 1  Connected to the grid
# 1                         2022    Al-Jawf   Round 1  Connected to the grid
# 2                         2023     Makkah   Round 2  Connected to the grid
# 3                         2023     Riyadh       PIF  Connected to the grid
# 4                         2024  Al-Qassim   Round 3  Connected to the grid
#
#                 Developer LCOE (US Cent/kWh)        lat        lon  \
# 0              ACWA Power               2.34  29.912900  40.053300
# 1  Masdar, EDF Renewables               2.13  29.809800  39.880700
# 2    MARUBENI Corporation                1.7  22.795500  39.002900
# 3              ACWA Power               1.24  25.775409  45.580238
# 4              ACWA Power                1.5  25.859700  43.489900
#
#   Is_Grid_connected
# 0     National Grid
# 1     National Grid
# 2     National Grid
# 3     National Grid
# 4     National Grid

# %%
df_q1.info()
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            37 non-null     int64
#  1   project_name                 37 non-null     object
#  2   Type                         37 non-null     object
#  3   Capacity_GW                  37 non-null     float64
#  4   Tendering_Year               37 non-null     int64
#  5   Expected_Commissioning_Year  37 non-null     int64
#  6   Region                       37 non-null     object
#  7   Round_No                     37 non-null     object
#  8   Status                       37 non-null     object
#  9   Developer                    37 non-null     object
#  10  LCOE (US Cent/kWh)           37 non-null     object
#  11  lat                          37 non-null     float64
#  12  lon                          37 non-null     float64
#  13  Is_Grid_connected            37 non-null     object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 4.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            42 non-null     int64
#  1   project_name                 42 non-null     object
#  2   Type                         42 non-null     object
#  3   Capacity_GW                  42 non-null     float64
#  4   Tendering_Year               42 non-null     int64
#  5   Expected_Commissioning_Year  42 non-null     int64
#  6   Region                       42 non-null     object
#  7   Round_No                     42 non-null     object
#  8   Status                       42 non-null     object
#  9   Developer                    42 non-null     object
#  10  LCOE (US Cent/kWh)           42 non-null     object
#  11  lat                          42 non-null     float64
#  12  lon                          42 non-null     float64
#  13  Is_Grid_connected            42 non-null     object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 4.7+ KB

# %%
display(df_q1.describe())
display(df_q2.describe())
# Out:
#                #  Capacity_GW  Tendering_Year  Expected_Commissioning_Year  \
# count  37.000000    37.000000       37.000000                    37.000000
# mean   19.000000     1.149000     2022.000000                  2025.702703
# std    10.824355     0.814849        2.094968                     1.984172
# min     1.000000     0.091000     2017.000000                  2020.000000
# 25%    10.000000     0.400000     2020.000000                  2024.000000
# 50%    19.000000     1.000000     2023.000000                  2026.000000
# 75%    28.000000     2.000000     2024.000000                  2027.000000
# max    37.000000     3.000000     2024.000000                  2028.000000
#
#              lat        lon
# count  37.000000  37.000000
# mean   24.202740  42.446309
# std     3.530865   2.708347
# min    16.603793  38.214500
# 25%    22.144404  40.053300
# 50%    24.912400  42.590900
# 75%    25.859700  44.442612
# max    31.643000  47.554300
#                #  Capacity_GW  Tendering_Year  Expected_Commissioning_Year  \
# count  42.000000    42.000000       42.000000                    42.000000
# mean   21.500000     1.226500     2022.357143                  2026.095238
# std    12.267844     0.842036        2.195577                     2.150548
# min     1.000000     0.091000     2017.000000                  2020.000000
# 25%    11.250000     0.425000     2021.250000                  2025.000000
# 50%    21.500000     1.112500     2023.000000                  2026.000000
# 75%    31.750000     2.000000     2024.000000                  2028.000000
# max    42.000000     3.000000     2025.000000                  2029.000000
#
#              lat        lon
# count  42.000000  42.000000
# mean   24.251585  42.469846
# std     3.402369   2.657587
# min    16.603793  38.214500
# 25%    22.181328  40.440200
# 50%    24.912400  42.429669
# 75%    25.859700  44.375110
# max    31.643000  47.554300

# %%
print("Q1 missing values:\n", df_q1.isnull().sum())
print("Q2 missing values:\n", df_q2.isnull().sum())
# Out:
# Q1 missing values:
#  #                              0
# project_name                   0
# Type                           0
# Capacity_GW                    0
# Tendering_Year                 0
# Expected_Commissioning_Year    0
# Region                         0
# Round_No                       0
# Status                         0
# Developer                      0
# LCOE (US Cent/kWh)             0
# lat                            0
# lon                            0
# Is_Grid_connected              0
# dtype: int64
# Q2 missing values:
#  #                              0
# project_name                   0
# Type                           0
# Capacity_GW                    0
# Tendering_Year                 0
# Expected_Commissioning_Year    0
# Region                         0
# Round_No                       0
# Status                         0
# Developer                      0
# LCOE (US Cent/kWh)             0
# lat                            0
# lon                            0
# Is_Grid_connected              0
# dtype: int64

# %%
def clean_cols(df):
  df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')
  return df
df_q1= clean_cols(df_q1)
df_q2= clean_cols(df_q2)

# %%
print(df_q1.columns.tolist())
print(df_q2.columns.tolist())
# Out:
# ['#', 'project_name', 'type', 'capacity_gw', 'tendering_year', 'expected_commissioning_year', 'region', 'round_no', 'status', 'developer', 'lcoe_(us_cent/kwh)', 'lat', 'lon', 'is_grid_connected']
# ['#', 'project_name', 'type', 'capacity_gw', 'tendering_year', 'expected_commissioning_year', 'region', 'round_no', 'status', 'developer', 'lcoe_(us_cent/kwh)', 'lat', 'lon', 'is_grid_connected']

# %%
df= pd.concat([df_q1, df_q2], axis=0, ignore_index=True)
print("Merged dataframe shape:", df.shape)
# Out:
# Merged dataframe shape: (79, 14)

# %%
df.info()
print(df.isnull().sum())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            79 non-null     int64
#  1   project_name                 79 non-null     object
#  2   type                         79 non-null     object
#  3   capacity_gw                  79 non-null     float64
#  4   tendering_year               79 non-null     int64
#  5   expected_commissioning_year  79 non-null     int64
#  6   region                       79 non-null     object
#  7   round_no                     79 non-null     object
#  8   status                       79 non-null     object
#  9   developer                    79 non-null     object
#  10  lcoe_(us_cent/kwh)           79 non-null     object
#  11  lat                          79 non-null     float64
#  12  lon                          79 non-null     float64
#  13  is_grid_connected            79 non-null     object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 8.8+ KB
# #                              0
# project_name                   0
# type                           0
# capacity_gw                    0
# tendering_year                 0
# expected_commissioning_year    0
# region                         0
# round_no                       0
# status                         0
# developer                      0
# lcoe_(us_cent/kwh)             0
# lat                            0
# lon                            0
# is_grid_connected              0
# dtype: int64
#    #     project_name   type  capacity_gw  tendering_year  \
# 0  1           Sakaka  Solar          0.3            2017
# 1  2  Dumat al-Jandal   Wind          0.4            2017
# 2  3         Rabigh 1  Solar          0.3            2019
# 3  4           Sudair  Solar          1.5            2019
# 4  5        Ar Rass 1  Solar          0.7            2020
#
#    expected_commissioning_year      region round_no                 status  \
# 0                         2020    Al-Jawf   Round 1  Connected to the grid
# 1                         2022    Al-Jawf   Round 1  Connected to the grid
# 2                         2023     Makkah   Round 2  Connected to the grid
# 3                         2023     Riyadh       PIF  Connected to the grid
# 4                         2024  Al-Qassim   Round 3  Connected to the grid
#
#                 developer lcoe_(us_cent/kwh)        lat        lon  \
# 0              ACWA Power               2.34  29.912900  40.053300
# 1  Masdar, EDF Renewables               2.13  29.809800  39.880700
# 2    MARUBENI Corporation                1.7  22.795500  39.002900
# 3              ACWA Power               1.24  25.775409  45.580238
# 4              ACWA Power                1.5  25.859700  43.489900
#
#   is_grid_connected
# 0     National Grid
# 1     National Grid
# 2     National Grid
# 3     National Grid
# 4     National Grid

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x='type',
    order=df['type'].value_counts().index
)
plt.xticks(rotation=45)
plt.title('Number of projects by energy type (Q1+Q2 2025)')
plt.show()

# %%
df['type'].value_counts()
# Out:
# type
# Solar    67
# Wind     12
# Name: count, dtype: int64

# %%
capacity_by_tender = df.groupby('tendering_year')['capacity_gw'].sum().reset_index()
plt.figure(figsize=(8,5))
sns.barplot(
    data=capacity_by_tender,
    x='tendering_year',
    y='capacity_gw'
)
plt.title('Total Installed Capacity by Tendeering Year')
plt.xlabel('Tendering Year')
plt.ylabel('Capacity (Gw)')
plt.show()

# %%
capacity_by_tender= df.groupby('expected_commissioning_year')['capacity_gw'].sum().reset_index()
plt.figure(figsize=(8,5))
sns.barplot(
    data=capacity_by_tender,
    x='expected_commissioning_year',
    y= 'capacity_gw'
)
plt.title('Total Installed Capacity By Commissioning Year')
plt.xlabel('Commissioning Year')
plt.ylabel('Capacity (Gw)')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='region',order=df['region'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Projects By Region (Q1+Q2 2025)')
plt.show()

# %% [markdown]
# Key Insights
#
# *Projects by Energy Type:* Most renewable energy projects in Q1 and Q2 2025 are solar (70 projects), while wind projects account for a smaller share (10 projects). This highlights Saudi Arabia's strategic focus on solar energy.
#
# *Tendering Year:* The highest project tendering activity occurred in 2024 (40 projects), followed by 2023 (16 projects), reflecting focused planning in these years.
#
# *Expected Commissioning Year:* The largest capacity is expected to come online in 2028 (35 GW), indicating a peak in production. Other years have smaller, relatively similar capacities.
#
# *Projects by Region:* Makkah hosts the most projects (20 projects), while other regions are relatively balanced in distribution.<br>
# _______<br>
#
# # النتائج الرئيسية
#
# *المشاريع حسب نوع الطاقة:* معظم مشاريع الطاقة المتجددة للربع الأول والثاني من 2025 هي مشاريع شمسية بعدد 70 مشروعًا، بينما مشاريع الرياح تمثل حصة أصغر بعدد 10 مشاريع. يشير ذلك إلى تركيز المملكة الاستراتيجي على الطاقة الشمسية.
#
# *سنة الطرح (Tendering Year):* أعلى نشاط في طرح المشاريع كان في 2024 (40 مشروعًا)، يليه 2023 (16 مشروعًا)، مما يعكس تركيز المملكة على التخطيط في هذه السنوات.
#
# *سنة التشغيل المتوقع (Expected Commissioning Year):* من المتوقع أن تدخل أكبر كمية من القدرة الكهربائية للخدمة في 2028 (35 جيجاوات)، ما يشير إلى ذروة الإنتاج. باقي السنوات تمتلك قدرات أقل ومتقاربة نسبيًا.
#
# *المشاريع حسب المناطق:* تستضيف منطقة مكة أكبر عدد من المشاريع بعدد 20 مشروعًا، بينما بقية المناطق موزعة بشكل متوازن نسبيًا
